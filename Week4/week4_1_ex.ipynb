# %%
import pandas as pd

# %%
data = pd.read_csv("D:/AI - Exercise/VietAI-x-CoderSchool/Week4/Week4_1_data.csv")

# %%
data.head()
# Out:
#    customer_id  year_of_birth educational_level marital_status  annual_income  \
# 0     20201701           1982        Graduation         Single        58138.0
# 1     20201702           1950        Graduation        Married        46344.0
# 2     20201703           1965        Graduation       Divorced        71613.0
# 3     20201704           1984        Graduation   Relationship        26646.0
# 4     20201705           1981               PhD        Widowed        58293.0
#
#   purhcase_date  recency  online_purchases  store_purchases  complaints  \
# 0      9/4/2012       58                 8                4           0
# 1      3/8/2014       38                 1                2           0
# 2     8/21/2013       26                 8               10           0
# 3     2/10/2014       26                 2                4           0
# 4     1/19/2014       94                 5                6           0
#
#    calls  intercoms
# 0      3         11
# 1      3         11
# ...

# %%
data.groupby("educational_level").size()
# Out:
# educational_level
# Basic            7
# Graduation     257
# High School     40
# Master          81
# PhD            114
# dtype: int64

# %%
data.sort_values(by="annual_income",ascending=False).head(20)
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 164     20201865           1952               PhD   Relationship
# 252     20201953           1997        Graduation        Widowed
# 203     20201904           1989               PhD         Single
# 124     20201825           1957        Graduation         Single
# 424     20202125           1967               PhD        Married
# 426     20202127           1957        Graduation        Married
# 140     20201841           1987            Master         Single
# 418     20202119           2000        Graduation         Single
# 116     20201817           2000        Graduation   Relationship
# 456     20202157           1957       High School         Single
# 109     20201810           1993            Master         Single
# 67      20201768           1984       High School       Divorced
# 120     20201821           1957            Master   Relationship
# ...

# %%
def task3(year, a_income):
    if year > 1960 and a_income > 50000:
        return year, a_income
data_task3 = data[(data["year_of_birth"] > 1960) & (data["annual_income"] > 50000)]
data[(data["year_of_birth"] > 1960) & (data["annual_income"] > 50000)]
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 0       20201701           1982        Graduation         Single
# 2       20201703           1965        Graduation       Divorced
# 4       20201705           1981               PhD        Widowed
# 5       20201706           1967            Master   Relationship
# 6       20201707           1971        Graduation       Divorced
# ..           ...            ...               ...            ...
# 486     20202187           1976            Master   Relationship
# 487     20202188           1974        Graduation        Married
# 493     20202194           1964            Master         Single
# 495     20202196           1962            Master       Divorced
# 496     20202197           1978        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
data_task3.sort_values(by="annual_income", ascending=False).head(20)
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 252     20201953           1997        Graduation        Widowed
# 203     20201904           1989               PhD         Single
# 424     20202125           1967               PhD        Married
# 140     20201841           1987            Master         Single
# 418     20202119           2000        Graduation         Single
# 116     20201817           2000        Graduation   Relationship
# 109     20201810           1993            Master         Single
# 67      20201768           1984       High School       Divorced
# 198     20201899           1984        Graduation        Widowed
# 407     20202108           1989               PhD   Relationship
# 142     20201843           1989        Graduation       Divorced
# 113     20201814           1997        Graduation        Married
# 102     20201803           1986        Graduation   Relationship
# ...

# %%
data[(data["marital_status"] == "Divorced")  | (data["marital_status"] == "Married")]
# Out:
#      customer_id  year_of_birth educational_level marital_status  \
# 1       20201702           1950        Graduation        Married
# 2       20201703           1965        Graduation       Divorced
# 6       20201707           1971        Graduation       Divorced
# 7       20201708           1985               PhD        Married
# 12      20201713           1959        Graduation       Divorced
# ..           ...            ...               ...            ...
# 488     20202189           1969        Graduation        Married
# 491     20202192           1976        Graduation       Divorced
# 494     20202195           1944               PhD       Divorced
# 495     20202196           1962            Master       Divorced
# 496     20202197           1978        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 1          46344.0      3/8/2014       38                 1                2
# ...

# %%
data.groupby("educational_level")["annual_income"].mean()
# Out:
# educational_level
# Basic          19514.571429
# Graduation     51607.827309
# High School    44154.717949
# Master         51191.700000
# PhD            55878.990991
# Name: annual_income, dtype: float64

# %%
data.groupby(["educational_level","marital_status"])["annual_income"].mean()
# Out:
# educational_level  marital_status
# Basic              Divorced          20797.000000
#                    Relationship      16443.000000
#                    Single            24882.000000
# Graduation         Divorced          52448.104167
#                    Married           49598.723077
#                    Relationship      53291.142857
#                    Single            51719.431034
#                    Widow             48097.500000
#                    Widowed           52221.600000
# High School        Divorced          49483.333333
#                    Married           38747.533333
#                    Relationship      51574.692308
#                    Single            48451.800000
#                    Widow             28457.000000
#                    Widowed           25592.000000
# Master             Divorced          46979.583333
#                    Married           52810.526316
#                    Relationship      46005.789474
# ...
